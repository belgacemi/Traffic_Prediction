# %% [markdown]
# # Building and Testing the performance of different models for the "Occupation Quota" of a Parisian street

# %% [markdown]
# ## ----------------------------------- Data loading and Preprocessing -----------------------------------

# %% [markdown]
# #### Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from sklearn.metrics import mean_squared_error
from sklearn import preprocessing
import time
import os
import tqdm.notebook as tq
import tensorflow as tf
import warnings
import matplotlib.image as mpimg
warnings.filterwarnings('ignore')
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.layers import Dropout
from sklearn.metrics import mean_squared_error
import tensorflow as tf
from keras.layers.normalization import BatchNormalization

# %% [markdown]
# #### Connect to Google Drive to get access to data later on

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/'Dossier partagé avec Iheb BELGACEM'/BCG_Hackathon
# Out:
# /content/drive/.shortcut-targets-by-id/1yXfewQDE3qy07N5B0XsOVSfqgaaXT3R7/Dossier partagé avec Iheb BELGACEM/BCG_Hackathon

# %% [markdown]
# #### Load dataframe and start preprocessing

# %%
data_path = "datasets/wash1.csv"
TARGET = "Taux d'occupation"
#TARGET = "Débit horaire"
dataframe = pd.read_csv(data_path)
dataframe.drop(["Unnamed: 0","index"], axis = 1 , inplace= True)
def set_date(df):
    df["Date et heure de comptage"] = pd.to_datetime(df["Date et heure de comptage"],format='%Y-%m-%d %H:%M:%S%z')
    return df
dataframe = set_date(dataframe)
dataframe.time = dataframe.time.apply(lambda x : int(x[:2]))
if TARGET == "Taux d'occupation": 
  dataframe.drop(["Débit horaire","mean_debit_horaire_past_week"], axis = 1 , inplace= True)
else : 
  dataframe.drop(["Taux d'occupation","mean_taux_occupation_past_week"], axis = 1 , inplace= True)
dataframe.drop(["Etat trafic","Libelle noeud amont","Libelle noeud aval","date"], axis = 1 , inplace= True)
dataframe
# Out:
#       Date et heure de comptage  Taux d'occupation  ...  couvrefeu  ferie
# 0     2019-11-14 04:00:00+01:00            3.20167  ...          0      0
# 1     2019-11-14 05:00:00+01:00            3.27389  ...          0      0
# 2     2019-11-14 06:00:00+01:00            5.28222  ...          0      0
# 3     2019-11-14 07:00:00+01:00            9.07722  ...          0      0
# 4     2019-11-14 08:00:00+01:00           15.51111  ...          0      0
# ...                         ...                ...  ...        ...    ...
# 9331  2020-11-29 20:00:00+01:00           13.09667  ...          0      0
# 9332  2020-11-29 21:00:00+01:00            7.50778  ...          0      0
# 9333  2020-11-29 22:00:00+01:00            4.38000  ...          0      0
# 9334  2020-11-29 23:00:00+01:00            2.11500  ...          0      0
# 9335  2020-11-30 00:00:00+01:00            1.16333  ...          0      0
#
# [9336 rows x 24 columns]

# %%
dataframe = dataframe.interpolate() #get rid of NaN values
#dataframe

# %%
dataframe.columns
# Out:
# Index(['Date et heure de comptage', 'Taux d'occupation', 'weekday',
#        'weekofyear', 'month', 'year', 'time', 'temp', 'dwpt', 'rhum', 'tavg',
#        'tmin', 'tmax', 'pres', 'mean_taux_occupation_past_week',
#        'taux_occupation_past_week', 'debit_horaire_past_week',
#        'taux_occupation_sae',
#        'retail_and_recreation_percent_change_from_baseline', 'confin_0',
#        'confin_1', 'confin_2', 'couvrefeu', 'ferie'],
#       dtype='object')

# %%
feat_time = ['weekday','weekofyear', 'month', 'year', 'time']
feat_meteo_d = ['tmin', 'tmax']
feat_meteo_h = ['temp', 'dwpt', 'rhum']
feat_conf_fer = ['confin_0','confin_1', 'confin_2', 'couvrefeu', 'ferie']
feat_mean = ['mean_taux_occupation_past_week'] if TARGET =="Taux d'occupation" else ['mean_debit_horaire_past_week']
feat_google = ['retail_and_recreation_percent_change_from_baseline']
feat_covid = ['taux_occupation_sae']

# %%
split_rate = 0.8
i_split = int(dataframe.shape[0] * split_rate)
df_train = dataframe[:i_split]
df_test = dataframe[i_split:]
tt = df_test['Date et heure de comptage']

# %% [markdown]
# ### Model1 - LSTM

# %% [markdown]
# ##### Libraries

# %%
to_scale = ['temp', 'dwpt', 'rhum','tmin', 'tmax','taux_occupation_sae','retail_and_recreation_percent_change_from_baseline']
for s in to_scale : 
  dataframe[s] = preprocessing.scale(dataframe[s])
dataframe
# Out:
#       Date et heure de comptage  Taux d'occupation  ...  couvrefeu  ferie
# 0     2019-11-14 04:00:00+01:00            3.20167  ...          0      0
# 1     2019-11-14 05:00:00+01:00            3.27389  ...          0      0
# 2     2019-11-14 06:00:00+01:00            5.28222  ...          0      0
# 3     2019-11-14 07:00:00+01:00            9.07722  ...          0      0
# 4     2019-11-14 08:00:00+01:00           15.51111  ...          0      0
# ...                         ...                ...  ...        ...    ...
# 9331  2020-11-29 20:00:00+01:00           13.09667  ...          0      0
# 9332  2020-11-29 21:00:00+01:00            7.50778  ...          0      0
# 9333  2020-11-29 22:00:00+01:00            4.38000  ...          0      0
# 9334  2020-11-29 23:00:00+01:00            2.11500  ...          0      0
# 9335  2020-11-30 00:00:00+01:00            1.16333  ...          0      0
#
# [9336 rows x 24 columns]

# %% [markdown]
# ###### Prepare data for THIS model, separate training and test set

# %%
def lstm_test_transform(x_data,e,num_steps) : 
  x,y = list(),list()
  for i in range(x_data.index[0], x_data.index[-1], 24*6) : 
    end_ix = i+num_steps
    if (end_ix + 24*6)>= x_data.index[-1] : 
      break
    seq_x = x_data[e].loc[i:end_ix].values
    seq_y = x_data.loc[end_ix:end_ix + 24*6,TARGET]
    x.append(seq_x)
    y.append(seq_y)
  x_array = np.array(x)
  y_array = np.array(y)
  return x_array , y_array
def lstm_data_transform(x_data,e,num_steps) : 
  x,y = list(),list()
  for i in range(x_data.shape[0]) : 
    end_ix = i+num_steps
    if (end_ix + 24*6)>= x_data.shape[0] : 
      break
    seq_x = x_data[e][i:end_ix].values
    seq_y = x_data.loc[end_ix:end_ix + 24*6,TARGET]
    x.append(seq_x)
    y.append(seq_y)
  x_array = np.array(x)
  y_array = np.array(y)
  return x_array , y_array

# %%
model_name = "LSTM"
if model_name not in os.listdir(os.getcwd()) : 
  os.mkdir(model_name)
  print('Created Folder')
experiments = [
               [TARGET]+feat_meteo_d+feat_conf_fer,
               [TARGET] +feat_meteo_d+feat_google,
               [TARGET] +feat_meteo_d+feat_covid, 
               [TARGET] + feat_time+feat_meteo_d+feat_conf_fer+feat_covid+feat_google]
count = 0
resume = []

for NB_DAYS in [4,8] : 
  for nb_lstm in [40]:
    for dropout in [0.001]:
      for e in tq.tqdm(experiments) : 
        print(e)
        timestep = datetime.datetime.now().strftime('%Y-%m-%d %H_%M_%S')
        os.mkdir(os.path.join(os.getcwd(),model_name,timestep))
        x_train, y_train = lstm_data_transform(df_train,e,num_steps = 24*7*NB_DAYS)
        x_test, y_test = lstm_test_transform(df_test,e, num_steps = 24*7*NB_DAYS)
        y_test = y_test.flatten()
        model = Sequential()
        model.add(LSTM(nb_lstm,input_shape = (x_train.shape[1],x_train.shape[2]), return_sequences=True))
        model.add(Dropout(dropout))
        model.add(LSTM(nb_lstm))
        model.add(Dropout(dropout))
        model.add(Dense(145,activation = 'relu'))
        model.summary()
        model.compile(loss = 'mse', optimizer = 'adam')
        model.summary()
        epochs = 300
        es =tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', mode ='min',verbose = 1, patience = 5)
        model.fit(x_train, y_train, epochs = epochs, verbose = 1, validation_split=0.15, callbacks = [es], batch_size = 1024)
        pred = model.predict(x_test).flatten()
        mse_tot = mean_squared_error(y_test,pred)
        mse_first = mean_squared_error(y_test[:24*6],pred[:24*6])
        record = {'name' : timestep , 'features' : e, "mse_tot":mse_tot , "mse_first" :mse_first ,"nb_lstm" : nb_lstm ,"nb_days":NB_DAYS, "dropout" : dropout, "path": os.path.join(os.getcwd(), model_name, timestep)}
        resume.append(record)
        pd.DataFrame.from_records([record]).to_csv(os.path.join(os.getcwd(),model_name,timestep,timestep+".csv"))
        fig = plt.figure(count)
        count = count + 1
        plt.plot(y_test , color = 'r',label = 'real values')
        plt.plot(pred , color ='b',label = 'prediected values')
        plt.title(model_name + "  ||  The MSE_tot: {}".format(mse_tot))
        fig.savefig(os.path.join(os.getcwd(),model_name,timestep,'total'+timestep+'.jpeg'))
        fig = plt.figure(count)
        count = count +1 
        plt.plot(tt[:24*6], y_test[:24*6] , color = 'r',label = 'real values')
        plt.plot(tt[:24*6], pred[:24*6] , color = 'b',label = 'predicted values')
        plt.title(model_name + "  ||  The MSE_first_6days: {}".format(mse_first))
        fig.savefig(os.path.join(os.getcwd(), model_name,timestep,'first'+timestep+'.jpeg'))
        pd.DataFrame.from_records(resume).sort_values('mse_tot').to_csv(model_name+".csv")
pd.DataFrame.from_records(resume).sort_values('mse_tot').to_csv(model_name+".csv")
resume = pd.read_csv(model_name+'.csv')
del resume['Unnamed: 0']
# Out:
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ["Taux d'occupation", 'tmin', 'tmax', 'confin_0', 'confin_1', 'confin_2', 'couvrefeu', 'ferie']
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_12 (LSTM)               (None, 672, 40)           7840
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 672, 40)           0
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 40)                12960
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 40)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 145)               5945
# =================================================================
# Total params: 26,745
# Trainable params: 26,745
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_12 (LSTM)               (None, 672, 40)           7840
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 672, 40)           0
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 40)                12960
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 40)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 145)               5945
# =================================================================
# Total params: 26,745
# Trainable params: 26,745
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 6/6 [==============================] - 2s 407ms/step - loss: 277.5034 - val_loss: 197.9897
# Epoch 2/300
# 6/6 [==============================] - 2s 274ms/step - loss: 274.7681 - val_loss: 194.6692
# Epoch 3/300
# 6/6 [==============================] - 2s 274ms/step - loss: 271.0874 - val_loss: 190.6741
# Epoch 4/300
# 6/6 [==============================] - 2s 274ms/step - loss: 266.7126 - val_loss: 185.9608
# Epoch 5/300
# 6/6 [==============================] - 2s 274ms/step - loss: 261.4653 - val_loss: 180.2673
# Epoch 6/300
# 6/6 [==============================] - 2s 275ms/step - loss: 255.2589 - val_loss: 173.9924
# 6/6 [==============================] - 2s 272ms/step - loss: 144.3937 - val_loss: 81.3234
# Epoch 37/300
# 6/6 [==============================] - 2s 269ms/step - loss: 141.0258 - val_loss: 78.9238
# Epoch 38/300
# 6/6 [==============================] - 2s 270ms/step - loss: 137.8722 - val_loss: 76.7565
# Epoch 39/300
# 6/6 [==============================] - 2s 274ms/step - loss: 134.9123 - val_loss: 74.7349
# Epoch 40/300
# 6/6 [==============================] - 2s 272ms/step - loss: 132.0843 - val_loss: 72.8934
# Epoch 41/300
# 6/6 [==============================] - 2s 272ms/step - loss: 129.4334 - val_loss: 71.2684
# Epoch 42/300
# 6/6 [==============================] - 2s 270ms/step - loss: 126.9368 - val_loss: 69.8557
# Epoch 43/300
# 6/6 [==============================] - 2s 273ms/step - loss: 124.6576 - val_loss: 69.0445
# Epoch 44/300
# 6/6 [==============================] - 2s 272ms/step - loss: 122.4993 - val_loss: 67.2620
# Epoch 45/300
# 6/6 [==============================] - 2s 274ms/step - loss: 120.4871 - val_loss: 66.2117
# Epoch 46/300
# 6/6 [==============================] - 2s 271ms/step - loss: 118.5994 - val_loss: 65.2792
# Epoch 47/300
# 6/6 [==============================] - 2s 276ms/step - loss: 116.9113 - val_loss: 64.4437
# Epoch 48/300
# 6/6 [==============================] - 2s 271ms/step - loss: 115.3868 - val_loss: 63.7057
# Epoch 49/300
# 6/6 [==============================] - 2s 272ms/step - loss: 113.8688 - val_loss: 63.1369
# Epoch 50/300
# 6/6 [==============================] - 2s 273ms/step - loss: 112.3198 - val_loss: 62.4981
# Epoch 51/300
# 6/6 [==============================] - 2s 275ms/step - loss: 110.8721 - val_loss: 62.0046
# Epoch 52/300
# 6/6 [==============================] - 2s 273ms/step - loss: 109.5600 - val_loss: 61.5841
# Epoch 53/300
# 6/6 [==============================] - 2s 274ms/step - loss: 108.3049 - val_loss: 61.2282
# Epoch 54/300
# 6/6 [==============================] - 2s 272ms/step - loss: 107.1092 - val_loss: 60.9294
# Epoch 55/300
# 6/6 [==============================] - 2s 270ms/step - loss: 105.9580 - val_loss: 60.6865
# Epoch 56/300
# 6/6 [==============================] - 2s 270ms/step - loss: 105.0029 - val_loss: 60.4935
# Epoch 57/300
# 6/6 [==============================] - 2s 271ms/step - loss: 104.1443 - val_loss: 60.3465
# Epoch 58/300
# 6/6 [==============================] - 2s 270ms/step - loss: 103.1452 - val_loss: 60.2449
# Epoch 59/300
# 6/6 [==============================] - 2s 274ms/step - loss: 102.2531 - val_loss: 60.1847
# Epoch 60/300
# 6/6 [==============================] - 2s 271ms/step - loss: 101.4667 - val_loss: 60.1624
# Epoch 61/300
# 6/6 [==============================] - 2s 275ms/step - loss: 100.5436 - val_loss: 60.1777
# Epoch 62/300
# 6/6 [==============================] - 2s 271ms/step - loss: 99.6783 - val_loss: 60.2231
# Epoch 63/300
# 6/6 [==============================] - 2s 275ms/step - loss: 98.7946 - val_loss: 60.3050
# Epoch 64/300
# 6/6 [==============================] - 2s 274ms/step - loss: 98.1819 - val_loss: 60.4104
# Epoch 65/300
# 6/6 [==============================] - 2s 272ms/step - loss: 97.3502 - val_loss: 60.5519
# Epoch 00065: early stopping
# WARNING:tensorflow:Model was constructed with shape (None, 672, 8) for input Tensor("lstm_12_input:0", shape=(None, 672, 8), dtype=float32), but it was called on an input with incompatible shape (None, 673, 8).
# ["Taux d'occupation", 'tmin', 'tmax', 'retail_and_recreation_percent_change_from_baseline']
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_14 (LSTM)               (None, 672, 40)           7200
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 672, 40)           0
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 40)                12960
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 40)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 145)               5945
# =================================================================
# Total params: 26,105
# Trainable params: 26,105
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_14 (LSTM)               (None, 672, 40)           7200
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 672, 40)           0
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 40)                12960
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 40)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 145)               5945
# =================================================================
# Total params: 26,105
# Trainable params: 26,105
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 6/6 [==============================] - 2s 396ms/step - loss: 277.8713 - val_loss: 198.4408
# Epoch 2/300
# 6/6 [==============================] - 2s 271ms/step - loss: 275.5604 - val_loss: 195.6517
# Epoch 3/300
# 6/6 [==============================] - 2s 274ms/step - loss: 272.3098 - val_loss: 192.1490
# Epoch 4/300
# 6/6 [==============================] - 2s 273ms/step - loss: 268.4081 - val_loss: 187.9957
# Epoch 5/300
# 6/6 [==============================] - 2s 272ms/step - loss: 263.7274 - val_loss: 183.1137
# Epoch 6/300
# 6/6 [==============================] - 2s 273ms/step - loss: 258.4328 - val_loss: 177.7782
# Epoch 7/300
# 6/6 [==============================] - 2s 276ms/step - loss: 252.7690 - val_loss: 172.2556
# Epoch 8/300
# 6/6 [==============================] - 2s 272ms/step - loss: 246.9971 - val_loss: 166.8811
# Epoch 9/300
# 6/6 [==============================] - 2s 271ms/step - loss: 241.3900 - val_loss: 161.7039
# Epoch 10/300
# 6/6 [==============================] - 2s 275ms/step - loss: 236.0333 - val_loss: 156.7112
# Epoch 11/300
# 6/6 [==============================] - 2s 267ms/step - loss: 230.8750 - val_loss: 151.9673
# Epoch 12/300
# 6/6 [==============================] - 2s 270ms/step - loss: 226.0042 - val_loss: 147.6241
# Epoch 13/300
# 6/6 [==============================] - 2s 268ms/step - loss: 221.5447 - val_loss: 143.6095
# Epoch 14/300
# 6/6 [==============================] - 2s 268ms/step - loss: 217.3850 - val_loss: 139.8875
# Epoch 15/300
# 6/6 [==============================] - 2s 269ms/step - loss: 213.5218 - val_loss: 136.4199
# Epoch 16/300
# 6/6 [==============================] - 2s 269ms/step - loss: 209.8559 - val_loss: 133.1197
# Epoch 17/300
# 6/6 [==============================] - 2s 266ms/step - loss: 206.1555 - val_loss: 129.9925
# Epoch 18/300
# 6/6 [==============================] - 2s 272ms/step - loss: 202.5223 - val_loss: 127.0329
# Epoch 19/300
# 6/6 [==============================] - 2s 271ms/step - loss: 198.8655 - val_loss: 124.0056
# Epoch 20/300
# 6/6 [==============================] - 2s 267ms/step - loss: 195.0498 - val_loss: 120.9205
# Epoch 21/300
# 6/6 [==============================] - 2s 271ms/step - loss: 191.3704 - val_loss: 117.7861
# Epoch 22/300
# 6/6 [==============================] - 2s 272ms/step - loss: 187.4304 - val_loss: 114.3960
# Epoch 23/300
# 6/6 [==============================] - 2s 272ms/step - loss: 183.3502 - val_loss: 110.8488
# Epoch 24/300
# Epoch 54/300
# 6/6 [==============================] - 2s 270ms/step - loss: 106.7926 - val_loss: 60.4965
# Epoch 55/300
# 6/6 [==============================] - 2s 273ms/step - loss: 105.8826 - val_loss: 60.2931
# Epoch 56/300
# 6/6 [==============================] - 2s 272ms/step - loss: 104.7664 - val_loss: 60.1324
# Epoch 57/300
# 6/6 [==============================] - 2s 275ms/step - loss: 103.8049 - val_loss: 60.0154
# Epoch 58/300
# 6/6 [==============================] - 2s 272ms/step - loss: 102.9306 - val_loss: 59.9398
# Epoch 59/300
# 6/6 [==============================] - 2s 275ms/step - loss: 101.9911 - val_loss: 59.8995
# Epoch 60/300
# 6/6 [==============================] - 2s 272ms/step - loss: 101.0393 - val_loss: 59.8941
# Epoch 61/300
# 6/6 [==============================] - 2s 271ms/step - loss: 100.1826 - val_loss: 59.9216
# Epoch 62/300
# 6/6 [==============================] - 2s 270ms/step - loss: 99.4407 - val_loss: 59.9801
# Epoch 63/300
# 6/6 [==============================] - 2s 271ms/step - loss: 99.0154 - val_loss: 60.0685
# Epoch 64/300
# 6/6 [==============================] - 2s 270ms/step - loss: 98.3133 - val_loss: 60.1802
# Epoch 65/300
# 6/6 [==============================] - 2s 273ms/step - loss: 97.5233 - val_loss: 60.3133
# Epoch 00065: early stopping
# WARNING:tensorflow:Model was constructed with shape (None, 672, 4) for input Tensor("lstm_14_input:0", shape=(None, 672, 4), dtype=float32), but it was called on an input with incompatible shape (None, 673, 4).
# ["Taux d'occupation", 'tmin', 'tmax', 'taux_occupation_sae']
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_16 (LSTM)               (None, 672, 40)           7200
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 672, 40)           0
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 40)                12960
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 40)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 145)               5945
# =================================================================
# Total params: 26,105
# Trainable params: 26,105
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_16 (LSTM)               (None, 672, 40)           7200
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 672, 40)           0
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 40)                12960
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 40)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 145)               5945
# =================================================================
# Total params: 26,105
# Trainable params: 26,105
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 6/6 [==============================] - 2s 406ms/step - loss: 278.1053 - val_loss: 198.6328
# Epoch 2/300
# 6/6 [==============================] - 2s 272ms/step - loss: 275.6890 - val_loss: 195.5318
# Epoch 3/300
# 6/6 [==============================] - 2s 272ms/step - loss: 272.0486 - val_loss: 191.3160
# Epoch 4/300
# 6/6 [==============================] - 2s 274ms/step - loss: 267.2536 - val_loss: 186.3261
# Epoch 5/300
# 6/6 [==============================] - 2s 272ms/step - loss: 261.7649 - val_loss: 180.7183
# Epoch 6/300
# 6/6 [==============================] - 2s 271ms/step - loss: 255.6224 - val_loss: 174.5645
# Epoch 7/300
# 6/6 [==============================] - 2s 272ms/step - loss: 249.1626 - val_loss: 168.4088
# Epoch 8/300
# 6/6 [==============================] - 2s 268ms/step - loss: 242.8483 - val_loss: 162.5910
# Epoch 9/300
# 6/6 [==============================] - 2s 271ms/step - loss: 236.8680 - val_loss: 157.2639
# Epoch 10/300
# 6/6 [==============================] - 2s 269ms/step - loss: 231.3919 - val_loss: 152.3633
# Epoch 11/300
# 6/6 [==============================] - 2s 271ms/step - loss: 226.3103 - val_loss: 147.7835
# Epoch 12/300
# 6/6 [==============================] - 2s 267ms/step - loss: 221.5543 - val_loss: 143.4572
# Epoch 13/300
# Epoch 43/300
# 6/6 [==============================] - 2s 271ms/step - loss: 122.1000 - val_loss: 66.4241
# Epoch 44/300
# 6/6 [==============================] - 2s 269ms/step - loss: 120.3053 - val_loss: 65.5247
# Epoch 45/300
# 6/6 [==============================] - 2s 270ms/step - loss: 118.5130 - val_loss: 64.7059
# Epoch 46/300
# 6/6 [==============================] - 2s 271ms/step - loss: 116.8203 - val_loss: 63.9671
# Epoch 47/300
# 6/6 [==============================] - 2s 272ms/step - loss: 115.3002 - val_loss: 63.3051
# Epoch 48/300
# 6/6 [==============================] - 2s 273ms/step - loss: 113.8461 - val_loss: 62.7165
# Epoch 49/300
# 6/6 [==============================] - 2s 274ms/step - loss: 113.1600 - val_loss: 62.2031
# Epoch 50/300
# 6/6 [==============================] - 2s 270ms/step - loss: 111.4685 - val_loss: 61.7399
# Epoch 51/300
# 6/6 [==============================] - 2s 274ms/step - loss: 110.1294 - val_loss: 61.3424
# Epoch 52/300
# 6/6 [==============================] - 2s 273ms/step - loss: 108.8494 - val_loss: 61.0000
# Epoch 53/300
# 6/6 [==============================] - 2s 274ms/step - loss: 107.6208 - val_loss: 60.7099
# Epoch 54/300
# 6/6 [==============================] - 2s 271ms/step - loss: 106.4062 - val_loss: 60.4712
# Epoch 55/300
# 6/6 [==============================] - 2s 272ms/step - loss: 105.2971 - val_loss: 60.2794
# Epoch 56/300
# 6/6 [==============================] - 2s 273ms/step - loss: 104.4001 - val_loss: 60.1332
# Epoch 57/300
# 6/6 [==============================] - 2s 270ms/step - loss: 103.3440 - val_loss: 60.0263
# Epoch 58/300
# 6/6 [==============================] - 2s 271ms/step - loss: 102.3531 - val_loss: 59.9601
# Epoch 59/300
# 6/6 [==============================] - 2s 271ms/step - loss: 101.4745 - val_loss: 59.9311
# Epoch 60/300
# 6/6 [==============================] - 2s 272ms/step - loss: 100.5988 - val_loss: 59.9367
# Epoch 61/300
# 6/6 [==============================] - 2s 273ms/step - loss: 99.7755 - val_loss: 59.9755
# Epoch 62/300
# 6/6 [==============================] - 2s 268ms/step - loss: 98.9691 - val_loss: 60.0459
# Epoch 63/300
# 6/6 [==============================] - 2s 272ms/step - loss: 98.3317 - val_loss: 60.1441
# Epoch 64/300
# 6/6 [==============================] - 2s 273ms/step - loss: 98.4835 - val_loss: 60.4176
# Epoch 00064: early stopping
# WARNING:tensorflow:Model was constructed with shape (None, 672, 4) for input Tensor("lstm_16_input:0", shape=(None, 672, 4), dtype=float32), but it was called on an input with incompatible shape (None, 673, 4).
# ["Taux d'occupation", 'weekday', 'weekofyear', 'month', 'year', 'time', 'tmin', 'tmax', 'confin_0', 'confin_1', 'confin_2', 'couvrefeu', 'ferie', 'taux_occupation_sae', 'retail_and_recreation_percent_change_from_baseline']
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_18 (LSTM)               (None, 672, 40)           8960
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 672, 40)           0
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 40)                12960
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 40)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 145)               5945
# =================================================================
# Total params: 27,865
# Trainable params: 27,865
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_18 (LSTM)               (None, 672, 40)           8960
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 672, 40)           0
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 40)                12960
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 40)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 145)               5945
# =================================================================
# Total params: 27,865
# Trainable params: 27,865
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
#
# 6/6 [==============================] - 2s 278ms/step - loss: 174.6240 - val_loss: 101.7506
# Epoch 32/300
# 6/6 [==============================] - 2s 279ms/step - loss: 173.2788 - val_loss: 100.5754
# Epoch 33/300
# 6/6 [==============================] - 2s 276ms/step - loss: 171.9903 - val_loss: 99.4769
# Epoch 34/300
# 6/6 [==============================] - 2s 276ms/step - loss: 170.7859 - val_loss: 98.4417
# Epoch 35/300
# 6/6 [==============================] - 2s 272ms/step - loss: 169.6475 - val_loss: 97.4804
# Epoch 36/300
# 6/6 [==============================] - 2s 277ms/step - loss: 168.5764 - val_loss: 96.5883
# Epoch 37/300
# 6/6 [==============================] - 2s 280ms/step - loss: 167.5908 - val_loss: 95.7462
# Epoch 38/300
# 6/6 [==============================] - 2s 274ms/step - loss: 166.6479 - val_loss: 94.9621
# Epoch 39/300
# 6/6 [==============================] - 2s 276ms/step - loss: 165.7636 - val_loss: 94.2352
# Epoch 40/300
# 6/6 [==============================] - 2s 271ms/step - loss: 164.9480 - val_loss: 93.5562
# Epoch 41/300
# 6/6 [==============================] - 2s 280ms/step - loss: 164.1846 - val_loss: 92.9275
# Epoch 42/300
# 6/6 [==============================] - 2s 279ms/step - loss: 163.4585 - val_loss: 92.3429
# Epoch 43/300
# 6/6 [==============================] - 2s 278ms/step - loss: 162.7683 - val_loss: 91.8039
# Epoch 44/300
# 6/6 [==============================] - 2s 275ms/step - loss: 162.1572 - val_loss: 91.3033
# Epoch 45/300
# 6/6 [==============================] - 2s 278ms/step - loss: 161.5787 - val_loss: 90.8387
# Epoch 46/300
# 6/6 [==============================] - 2s 280ms/step - loss: 161.0156 - val_loss: 90.4162
# Epoch 47/300
# 6/6 [==============================] - 2s 277ms/step - loss: 160.5128 - val_loss: 90.0214
# Epoch 48/300
# 6/6 [==============================] - 2s 276ms/step - loss: 160.0390 - val_loss: 89.6612
# Epoch 49/300
# 6/6 [==============================] - 2s 276ms/step - loss: 159.6154 - val_loss: 89.3274
# Epoch 50/300
# 6/6 [==============================] - 2s 273ms/step - loss: 159.2020 - val_loss: 89.0221
# Epoch 51/300
# 6/6 [==============================] - 2s 274ms/step - loss: 158.8220 - val_loss: 88.7426
# Epoch 52/300
# 6/6 [==============================] - 2s 274ms/step - loss: 158.4794 - val_loss: 88.4875
# Epoch 53/300
# 6/6 [==============================] - 2s 277ms/step - loss: 158.1392 - val_loss: 88.2558
# Epoch 54/300
# 6/6 [==============================] - 2s 280ms/step - loss: 157.8594 - val_loss: 88.0452
# Epoch 55/300
# 6/6 [==============================] - 2s 278ms/step - loss: 157.5724 - val_loss: 87.8543
# Epoch 56/300
# 3/6 [==============>...............] - ETA: 0s - loss: 157.3881

# %%
resume

# %%
for i in range(10) : 
  print(i)
  print("MSE_tot: {}    ||     Features: {}".format( str(resume.loc[i,"mse_tot"]), resume.loc[i,'features']))

# %%
for i in range(5) : 
  print(resume.loc[i])
  path = resume.loc[i,"path"]
  for file in os.listdir(path) :
    if '.jpeg' in file : 
      img = mpimg.imread(os.path.join(resume.loc[i,'path'],file))
      plt.imshow(img)
      plt.show()
